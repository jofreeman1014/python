# %% [markdown]
# # WeatherPy
# ----

# %% [markdown]
# ## Notebook and API Setup

# %%
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests 
import time
import pprint
import openweathermapy.core as owm

# Import datetime for today's (execution) date
import datetime
now = datetime.datetime.now().strftime("%Y-%m-%d")

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "Outputs/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)
settings = {"units": "Imperial", "appid": api_key}

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination, save non-repeating entries.
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
if len(cities) < 500:
    print("WARNING: UNDER 500 DATA POINTS, PLEASE RUN AGAIN FOR MORE")
print(f"Initialized {len(cities)} city names.")
# Out:
# Initialized 886 city names.

# %%
cities[:5]
# Out:
# ['punta arenas', 'namatanai', 'falmouth', 'palabuhanratu', 'mar del plata']

# %% [markdown]
# ## Performing API Calls

# %% [markdown]
# #### Preparing Dataframe

# %%
# Dataframe setup
weather_df = pd.DataFrame()
weather_df["City"] = cities
weather_df["Country"] = ""
weather_df["Lat"] = ""
weather_df["Lng"] = ""
weather_df["Date"] = ""
weather_df["Max Temp"] = ""
weather_df["Humidity"] = ""
weather_df["Clouds"] = ""
weather_df["Wind Speed"] = ""

# %% [markdown]
# #### Collecting Data through API Pulls

# %%
# Populate dataframe using API pulls
missedtot = 0 # variable to keep up with data loss
for i in range(len(cities)): 
    try:
        ctmp = weather_df["City"][i]
        tmp = owm.get_current(weather_df["City"][i], **settings)
        weather_df.loc[i, 'Country'] = tmp['sys']['country']        
        weather_df.loc[i, 'Lat'] = tmp['coord']['lat']
        weather_df.loc[i, 'Lng'] = tmp['coord']['lon']
        weather_df.loc[i, 'Date'] = tmp['dt']
        weather_df.loc[i, 'Max Temp'] = tmp['main']['temp_max']
        weather_df.loc[i, 'Humidity'] = tmp['main']['humidity']
        weather_df.loc[i, 'Clouds'] = tmp['clouds']['all']
        weather_df.loc[i, 'Wind Speed'] = tmp['wind']['speed']
        time.sleep(1.0001) # Pull limit is 60/min
        print(f"{i} out of {len(cities)} | Found data for: {ctmp.title()}")
    except: 
        missedtot +=1
        print(f"No data for index ({i})... skipping.")       
print(f"For {len(cities)}, dropped {missedtot} ({round(missedtot/len(cities)*100,1)}% lost)")
print("Cleaning and saving dataframe...")

# Clean and save data
weather_df.replace('', np.nan, inplace=True)
weather_df = weather_df.dropna()
weather_df.to_csv(output_data_file, index_label="City_ID")
weather_df.head()
# Out:
# 0 out of 886 | Found data for: Punta Arenas
# 1 out of 886 | Found data for: Namatanai
# 2 out of 886 | Found data for: Falmouth
# No data for index (3)... skipping.
# 4 out of 886 | Found data for: Mar Del Plata
# 5 out of 886 | Found data for: Sabha
# No data for index (6)... skipping.
# 7 out of 886 | Found data for: Zhuhai
# 8 out of 886 | Found data for: Klaksvik
# 9 out of 886 | Found data for: Hilo
# 10 out of 886 | Found data for: Bluff
# 11 out of 886 | Found data for: Upernavik
# 12 out of 886 | Found data for: Thompson
# 13 out of 886 | Found data for: Sergeyevka
# 14 out of 886 | Found data for: Atuona
# 15 out of 886 | Found data for: Vaini
# 16 out of 886 | Found data for: Hithadhoo
# 17 out of 886 | Found data for: Rikitea
# 18 out of 886 | Found data for: Huarmey
# No data for index (19)... skipping.
# 20 out of 886 | Found data for: Aksaray
# 21 out of 886 | Found data for: Ushuaia
# 22 out of 886 | Found data for: San Pedro Buenavista
# 23 out of 886 | Found data for: Kavaratti
# 24 out of 886 | Found data for: San Andres
# 25 out of 886 | Found data for: Port Moresby
# 26 out of 886 | Found data for: Kodiak
# 27 out of 886 | Found data for: Cape Town
# 28 out of 886 | Found data for: Camacha
# 29 out of 886 | Found data for: Jamestown
# 30 out of 886 | Found data for: Mount Gambier
# No data for index (31)... skipping.
# 32 out of 886 | Found data for: Ayagoz
# 33 out of 886 | Found data for: Morehead
# 34 out of 886 | Found data for: Kruisfontein
# 35 out of 886 | Found data for: Komsomolskiy
# No data for index (36)... skipping.
# 37 out of 886 | Found data for: Behshahr
# 38 out of 886 | Found data for: Lebu
# 39 out of 886 | Found data for: Estelle
# No data for index (40)... skipping.
# 41 out of 886 | Found data for: Chuy
# 42 out of 886 | Found data for: Flinders
# 43 out of 886 | Found data for: Hobart
# 44 out of 886 | Found data for: Santo Domingo
# 45 out of 886 | Found data for: Bucerias
# 46 out of 886 | Found data for: Ukiah
# No data for index (47)... skipping.
# 48 out of 886 | Found data for: Constitucion
# 49 out of 886 | Found data for: East London
# 50 out of 886 | Found data for: Lorengau
# 51 out of 886 | Found data for: Qui Nhon
# 52 out of 886 | Found data for: Wanning
# 53 out of 886 | Found data for: Colwyn Bay
# 54 out of 886 | Found data for: Saint-Philippe
# 55 out of 886 | Found data for: Krasnaya Gora
# 56 out of 886 | Found data for: Albany
# 57 out of 886 | Found data for: Whitehorse
# 58 out of 886 | Found data for: Arraial Do Cabo
# 59 out of 886 | Found data for: Port Alfred
# 60 out of 886 | Found data for: Hambantota
# 61 out of 886 | Found data for: Dayong
# 62 out of 886 | Found data for: Qaanaaq
# No data for index (63)... skipping.
# No data for index (64)... skipping.
# 65 out of 886 | Found data for: Nanortalik
# 66 out of 886 | Found data for: Ribeira Grande
# 67 out of 886 | Found data for: Chicama
# 68 out of 886 | Found data for: Tautira
# No data for index (69)... skipping.
# 70 out of 886 | Found data for: Cidreira
# 71 out of 886 | Found data for: Mataura
# No data for index (72)... skipping.
# 73 out of 886 | Found data for: Luanda
# 74 out of 886 | Found data for: Torbay
# 75 out of 886 | Found data for: Busselton
# 76 out of 886 | Found data for: Kapaa
# 77 out of 886 | Found data for: Khatanga
# 78 out of 886 | Found data for: Kirakira
# 79 out of 886 | Found data for: Acarau
# No data for index (80)... skipping.
# 81 out of 886 | Found data for: Ambilobe
# 82 out of 886 | Found data for: Chokurdakh
# 83 out of 886 | Found data for: Sao Filipe
# 84 out of 886 | Found data for: Dukat
# 85 out of 886 | Found data for: Mackenzie
# 86 out of 886 | Found data for: Bereda
# 87 out of 886 | Found data for: Baffa
# 88 out of 886 | Found data for: Tuktoyaktuk
# 89 out of 886 | Found data for: Half Moon Bay
# 90 out of 886 | Found data for: Provideniya
# 91 out of 886 | Found data for: Cabedelo
# 92 out of 886 | Found data for: Chilca
# 93 out of 886 | Found data for: Lata
# 94 out of 886 | Found data for: Chifeng
# 95 out of 886 | Found data for: Praia Da Vitoria
# 96 out of 886 | Found data for: Nhulunbuy
# 97 out of 886 | Found data for: Petropavlovsk-Kamchatskiy
# 98 out of 886 | Found data for: Gamba
# 99 out of 886 | Found data for: Lawton
# 100 out of 886 | Found data for: Carnarvon
# 101 out of 886 | Found data for: Najran
# 102 out of 886 | Found data for: Terrace
# 103 out of 886 | Found data for: Houma
# No data for index (104)... skipping.
# 105 out of 886 | Found data for: Khani
# No data for index (106)... skipping.
# 107 out of 886 | Found data for: Svetlaya
# 108 out of 886 | Found data for: Luan
# 109 out of 886 | Found data for: Broome
# No data for index (110)... skipping.
# 111 out of 886 | Found data for: San Patricio
# 112 out of 886 | Found data for: Victoria
# 113 out of 886 | Found data for: Puerto Ayora
# No data for index (114)... skipping.
# 115 out of 886 | Found data for: San Policarpo
# 116 out of 886 | Found data for: Barra
# 117 out of 886 | Found data for: Teknaf
# 118 out of 886 | Found data for: Ponta Do Sol
# 119 out of 886 | Found data for: Pemba
# 120 out of 886 | Found data for: Aksha
# 121 out of 886 | Found data for: Galveston
# 122 out of 886 | Found data for: Georgetown
# No data for index (123)... skipping.
# 124 out of 886 | Found data for: Andenes
# 125 out of 886 | Found data for: Codrington
# 126 out of 886 | Found data for: Cururupu
# 127 out of 886 | Found data for: Neiafu
# 128 out of 886 | Found data for: Nome
# 129 out of 886 | Found data for: Anadyr
# 130 out of 886 | Found data for: Avenal
# 131 out of 886 | Found data for: Saldanha
# 132 out of 886 | Found data for: Taltal
# No data for index (133)... skipping.
# 134 out of 886 | Found data for: Arlit
# 135 out of 886 | Found data for: Hermanus
# 136 out of 886 | Found data for: Chadiza
# 137 out of 886 | Found data for: Olutanga
# 138 out of 886 | Found data for: Rocha
# 139 out of 886 | Found data for: Ha Tinh
# 140 out of 886 | Found data for: Poum
# 141 out of 886 | Found data for: Talcahuano
# 142 out of 886 | Found data for: Antofagasta
# 143 out of 886 | Found data for: Khrebtovaya
# 144 out of 886 | Found data for: Bilma
# 145 out of 886 | Found data for: Yunyang
# 146 out of 886 | Found data for: Cabo San Lucas
# 147 out of 886 | Found data for: Bonfim
# 148 out of 886 | Found data for: Luderitz
# 149 out of 886 | Found data for: Yar-Sale
# 150 out of 886 | Found data for: Yellowknife
# 151 out of 886 | Found data for: Svetlogorsk
# 152 out of 886 | Found data for: Eureka
# 153 out of 886 | Found data for: Namibe
# 154 out of 886 | Found data for: Bilibino
# 155 out of 886 | Found data for: Grindavik
# 156 out of 886 | Found data for: Prince George
# 157 out of 886 | Found data for: La Ronge
# 158 out of 886 | Found data for: Sao Jose Da Coroa Grande
# 159 out of 886 | Found data for: Nikolskoye
# 160 out of 886 | Found data for: Havoysund
# No data for index (161)... skipping.
# 162 out of 886 | Found data for: Bengkulu
# 163 out of 886 | Found data for: Butaritari
# 164 out of 886 | Found data for: Port Elizabeth
# 165 out of 886 | Found data for: Bathsheba
# 166 out of 886 | Found data for: Bredasdorp
# 167 out of 886 | Found data for: Yurimaguas
# 168 out of 886 | Found data for: Necochea
# No data for index (169)... skipping.
# 170 out of 886 | Found data for: Avera
# 171 out of 886 | Found data for: Norman Wells
# 172 out of 886 | Found data for: Coahuayana
# No data for index (173)... skipping.
# 174 out of 886 | Found data for: Iskateley
# 175 out of 886 | Found data for: Ilulissat
# 176 out of 886 | Found data for: Mahebourg
# 177 out of 886 | Found data for: Puerto Barrios
# 178 out of 886 | Found data for: Airai
# 179 out of 886 | Found data for: Vao
# 180 out of 886 | Found data for: Faya
# 181 out of 886 | Found data for: Luba
# 182 out of 886 | Found data for: Hasaki
# 183 out of 886 | Found data for: Guerrero Negro
# 184 out of 886 | Found data for: Haines Junction
# 185 out of 886 | Found data for: Hamilton
# No data for index (186)... skipping.
# 187 out of 886 | Found data for: Berlevag
# 188 out of 886 | Found data for: Zlobin
# 189 out of 886 | Found data for: Kaitangata
# 190 out of 886 | Found data for: Mogadishu
# 191 out of 886 | Found data for: Aripuana
# 192 out of 886 | Found data for: Sorland
# 193 out of 886 | Found data for: Jaciara
# 194 out of 886 | Found data for: Banda Aceh
# 195 out of 886 | Found data for: Shimanovsk
# 196 out of 886 | Found data for: Touros
# 197 out of 886 | Found data for: Lavrentiya
# 198 out of 886 | Found data for: Boundiali
# 199 out of 886 | Found data for: Baruun-Urt
# 200 out of 886 | Found data for: New Norfolk
# 201 out of 886 | Found data for: Coquimbo
# 202 out of 886 | Found data for: Margate
# No data for index (203)... skipping.
# 204 out of 886 | Found data for: Castro
# 205 out of 886 | Found data for: Udachnyy
# 206 out of 886 | Found data for: Saskylakh
# 207 out of 886 | Found data for: Ust-Uda
# No data for index (208)... skipping.
# 209 out of 886 | Found data for: Dali
# 210 out of 886 | Found data for: Storforshei
# 211 out of 886 | Found data for: Mokrous
# 212 out of 886 | Found data for: Waingapu
# 213 out of 886 | Found data for: Hofn
# 214 out of 886 | Found data for: Anchorage
# 215 out of 886 | Found data for: Port Hedland
# 216 out of 886 | Found data for: Yarim
# 217 out of 886 | Found data for: Manokwari
# 218 out of 886 | Found data for: Quatre Cocos
# No data for index (219)... skipping.
# 220 out of 886 | Found data for: Fairbanks
# 221 out of 886 | Found data for: Aranos
# 222 out of 886 | Found data for: Saint George
# 223 out of 886 | Found data for: Bandarbeyla
# 224 out of 886 | Found data for: Evensk
# 225 out of 886 | Found data for: Payakumbuh
# 226 out of 886 | Found data for: Roma
# No data for index (227)... skipping.
# 228 out of 886 | Found data for: San Cristobal
# 229 out of 886 | Found data for: Skaudvile
# 230 out of 886 | Found data for: Tasiilaq
# No data for index (231)... skipping.
# 232 out of 886 | Found data for: Marawi
# 233 out of 886 | Found data for: Salvador
# 234 out of 886 | Found data for: Krasnogorskoye
# 235 out of 886 | Found data for: Ucluelet
# 236 out of 886 | Found data for: Enniskerry
# 237 out of 886 | Found data for: Sampit
# 238 out of 886 | Found data for: Japura
# 239 out of 886 | Found data for: Nantucket
# 240 out of 886 | Found data for: Sand Springs
# 241 out of 886 | Found data for: Chabahar
# 242 out of 886 | Found data for: Grass Valley
# 243 out of 886 | Found data for: Narasannapeta
# 244 out of 886 | Found data for: Myre
# 245 out of 886 | Found data for: Hulan
# 246 out of 886 | Found data for: Oranjemund
# 247 out of 886 | Found data for: Orchard Homes
# 248 out of 886 | Found data for: Pozo Colorado
# No data for index (249)... skipping.
# 250 out of 886 | Found data for: Moindou
# 251 out of 886 | Found data for: Kushima
# 252 out of 886 | Found data for: Batagay
# 253 out of 886 | Found data for: San Quintin
# 254 out of 886 | Found data for: Chitral
# 255 out of 886 | Found data for: Caravelas
# 256 out of 886 | Found data for: Mbanza-Ngungu
# 257 out of 886 | Found data for: Astoria
# 258 out of 886 | Found data for: Buraydah
# 259 out of 886 | Found data for: Kalmunai
# 260 out of 886 | Found data for: Port-Gentil
# 261 out of 886 | Found data for: Avarua
# 262 out of 886 | Found data for: Druskininkai
# 263 out of 886 | Found data for: Halifax
# 264 out of 886 | Found data for: Acapulco
# 265 out of 886 | Found data for: Jumla
# 266 out of 886 | Found data for: Santa Rosa
# 267 out of 886 | Found data for: Tartagal
# 268 out of 886 | Found data for: Suining
# 269 out of 886 | Found data for: Duluth
# 270 out of 886 | Found data for: Benicarlo
# 271 out of 886 | Found data for: Trastenik
# 272 out of 886 | Found data for: Do Gonbadan
# 273 out of 886 | Found data for: Sinnamary
# 274 out of 886 | Found data for: Tomatlan
# 275 out of 886 | Found data for: Beringovskiy
# No data for index (276)... skipping.
# 277 out of 886 | Found data for: Sungaipenuh
# 278 out of 886 | Found data for: The Pas
# 279 out of 886 | Found data for: Longyearbyen
# 280 out of 886 | Found data for: Bairnsdale
# 281 out of 886 | Found data for: Lingao
# 282 out of 886 | Found data for: Vanimo
# 283 out of 886 | Found data for: Pevek
# 284 out of 886 | Found data for: Richards Bay
# 285 out of 886 | Found data for: Eyl
# 286 out of 886 | Found data for: Karangampel
# No data for index (287)... skipping.
# 288 out of 886 | Found data for: Agadez
# 289 out of 886 | Found data for: Te Anau
# 290 out of 886 | Found data for: Ixtapa
# 291 out of 886 | Found data for: Fairview
# 292 out of 886 | Found data for: Bethel
# 293 out of 886 | Found data for: The Valley
# 294 out of 886 | Found data for: Yantal
# 295 out of 886 | Found data for: Antalaha
# 296 out of 886 | Found data for: Hammerfest
# 297 out of 886 | Found data for: Buchanan
# 298 out of 886 | Found data for: Gol
# 299 out of 886 | Found data for: Saint Anthony
# 300 out of 886 | Found data for: Dikson
# 301 out of 886 | Found data for: Mulatupo
# 302 out of 886 | Found data for: Iqaluit
# No data for index (303)... skipping.
# 304 out of 886 | Found data for: Samana
# 305 out of 886 | Found data for: Leningradskiy
# No data for index (306)... skipping.
# 307 out of 886 | Found data for: Trinidad
# 308 out of 886 | Found data for: Atar
# 309 out of 886 | Found data for: Medina
# 310 out of 886 | Found data for: Batagay-Alyta
# 311 out of 886 | Found data for: Sembe
# 312 out of 886 | Found data for: Baherden
# 313 out of 886 | Found data for: Manggar
# 314 out of 886 | Found data for: Wamba
# 315 out of 886 | Found data for: Waipawa
# 316 out of 886 | Found data for: Kieta
# 317 out of 886 | Found data for: Tuatapere
# 318 out of 886 | Found data for: Meulaboh
# 319 out of 886 | Found data for: Sobolevo
# No data for index (320)... skipping.
# 321 out of 886 | Found data for: Geraldton
# 322 out of 886 | Found data for: Dapaong
# 323 out of 886 | Found data for: Bredy
# 324 out of 886 | Found data for: Saint-Nazaire
# 325 out of 886 | Found data for: Ca Mau
# 326 out of 886 | Found data for: Nan
# 327 out of 886 | Found data for: Mbuguni
# 328 out of 886 | Found data for: Sisimiut
# 329 out of 886 | Found data for: Puerto Leguizamo
# 330 out of 886 | Found data for: Kedrovyy
# 331 out of 886 | Found data for: Hansot
# 332 out of 886 | Found data for: Darhan
# No data for index (333)... skipping.
# 334 out of 886 | Found data for: Taoudenni
# 335 out of 886 | Found data for: Barrow
# 336 out of 886 | Found data for: Vypolzovo
# 337 out of 886 | Found data for: Katherine
# 338 out of 886 | Found data for: Narsaq
# 339 out of 886 | Found data for: Sioux Lookout
# 340 out of 886 | Found data for: Kupang
# 341 out of 886 | Found data for: Manakara
# 342 out of 886 | Found data for: Cherskiy
# 343 out of 886 | Found data for: Arrifes
# 344 out of 886 | Found data for: Shieli
# 345 out of 886 | Found data for: Subirana
# 346 out of 886 | Found data for: Sitka
# 347 out of 886 | Found data for: Dingle
# 348 out of 886 | Found data for: Zhob
# No data for index (349)... skipping.
# 350 out of 886 | Found data for: College
# 351 out of 886 | Found data for: Salalah
# 352 out of 886 | Found data for: Faanui
# 353 out of 886 | Found data for: Tiksi
# 354 out of 886 | Found data for: Soller
# 355 out of 886 | Found data for: General Roca
# 356 out of 886 | Found data for: Champerico
# No data for index (357)... skipping.
# 358 out of 886 | Found data for: San-Pedro
# 359 out of 886 | Found data for: Cairns
# 360 out of 886 | Found data for: Snasa
# 361 out of 886 | Found data for: Antalya
# 362 out of 886 | Found data for: Wenling
# 363 out of 886 | Found data for: Hillsborough
# 364 out of 886 | Found data for: Santa Maria
# 365 out of 886 | Found data for: Sur
# 366 out of 886 | Found data for: Newport
# 367 out of 886 | Found data for: Mwinilunga
# 368 out of 886 | Found data for: Mandapam
# 369 out of 886 | Found data for: Esna
# 370 out of 886 | Found data for: Sept-Iles
# 371 out of 886 | Found data for: Naze
# 372 out of 886 | Found data for: Kozlovka
# 373 out of 886 | Found data for: Ouesso
# 374 out of 886 | Found data for: Domoni
# 375 out of 886 | Found data for: Vila Velha
# 376 out of 886 | Found data for: Kavieng
# 377 out of 886 | Found data for: Marion
# 378 out of 886 | Found data for: Tera
# 379 out of 886 | Found data for: Shangqiu
# 380 out of 886 | Found data for: Domat
# 381 out of 886 | Found data for: Manyana
# 382 out of 886 | Found data for: Praya
# 383 out of 886 | Found data for: Summerville
# 384 out of 886 | Found data for: Inongo
# 385 out of 886 | Found data for: Kharp
# 386 out of 886 | Found data for: Grand-Lahou
# 387 out of 886 | Found data for: Mangan
# 388 out of 886 | Found data for: Lompoc
# 389 out of 886 | Found data for: Malibu
# 390 out of 886 | Found data for: Odda
# 391 out of 886 | Found data for: Olafsvik
# 392 out of 886 | Found data for: Chake Chake
# 393 out of 886 | Found data for: Long Beach
# 394 out of 886 | Found data for: Weligama
# 395 out of 886 | Found data for: Sao Gabriel Da Cachoeira
# 396 out of 886 | Found data for: Vernon
# 397 out of 886 | Found data for: Mpanda
# No data for index (398)... skipping.
# 399 out of 886 | Found data for: Oksfjord
# 400 out of 886 | Found data for: Suzun
# 401 out of 886 | Found data for: Gua Musang
# 402 out of 886 | Found data for: Malanje
# 403 out of 886 | Found data for: Pangnirtung
# 404 out of 886 | Found data for: Gouyave
# 405 out of 886 | Found data for: Southbridge
# 406 out of 886 | Found data for: Vangaindrano
# 407 out of 886 | Found data for: Ketchikan
# 408 out of 886 | Found data for: Chateauroux
# No data for index (409)... skipping.
# 410 out of 886 | Found data for: Anaconda
# 411 out of 886 | Found data for: Balabac
# 412 out of 886 | Found data for: Zhangye
# 413 out of 886 | Found data for: Asau
# 414 out of 886 | Found data for: Henties Bay
# 415 out of 886 | Found data for: Dondaicha
# 416 out of 886 | Found data for: Havre-Saint-Pierre
# 417 out of 886 | Found data for: Somerset
# 418 out of 886 | Found data for: Kungurtug
# 419 out of 886 | Found data for: Glenwood Springs
# 420 out of 886 | Found data for: Aldan
# 421 out of 886 | Found data for: Samarai
# 422 out of 886 | Found data for: Ornskoldsvik
# 423 out of 886 | Found data for: Madison
# 424 out of 886 | Found data for: Spoleto
# 425 out of 886 | Found data for: Paamiut
# 426 out of 886 | Found data for: Novikovo
# No data for index (427)... skipping.
# No data for index (428)... skipping.
# 429 out of 886 | Found data for: Goderich
# 430 out of 886 | Found data for: Kirksville
# 431 out of 886 | Found data for: Ous
# 432 out of 886 | Found data for: Monchegorsk
# No data for index (433)... skipping.
# 434 out of 886 | Found data for: Marzuq
# 435 out of 886 | Found data for: Mago
# 436 out of 886 | Found data for: Kulhudhuffushi
# 437 out of 886 | Found data for: Mumford
# 438 out of 886 | Found data for: Darab
# 439 out of 886 | Found data for: Erzin
# 440 out of 886 | Found data for: Yerbogachen
# 441 out of 886 | Found data for: Cayenne
# 442 out of 886 | Found data for: Sirpur
# 443 out of 886 | Found data for: Esperance
# No data for index (444)... skipping.
# No data for index (445)... skipping.
# 446 out of 886 | Found data for: Ilebo
# 447 out of 886 | Found data for: Kihei
# 448 out of 886 | Found data for: Pulandian
# No data for index (449)... skipping.
# 450 out of 886 | Found data for: Chaman
# 451 out of 886 | Found data for: Labuhan
# No data for index (452)... skipping.
# 453 out of 886 | Found data for: Vermilion
# 454 out of 886 | Found data for: Skjervoy
# 455 out of 886 | Found data for: Jiexiu
# 456 out of 886 | Found data for: Hovd
# No data for index (457)... skipping.
# 458 out of 886 | Found data for: Mayo
# 459 out of 886 | Found data for: Jaru
# 460 out of 886 | Found data for: Sarahan
# 461 out of 886 | Found data for: Sherlovaya Gora
# 462 out of 886 | Found data for: Harper
# 463 out of 886 | Found data for: Shunyi
# No data for index (464)... skipping.
# 465 out of 886 | Found data for: Xinzhou
# 466 out of 886 | Found data for: Lishui
# 467 out of 886 | Found data for: Matamoros
# 468 out of 886 | Found data for: Pontianak
# 469 out of 886 | Found data for: Rafraf
# 470 out of 886 | Found data for: Sumbe
# 471 out of 886 | Found data for: Itarema
# No data for index (472)... skipping.
# 473 out of 886 | Found data for: Senador Jose Porfirio
# 474 out of 886 | Found data for: Kita
# 475 out of 886 | Found data for: Skibbereen
# 476 out of 886 | Found data for: Winnemucca
# 477 out of 886 | Found data for: Bastrop
# 478 out of 886 | Found data for: Miri
# 479 out of 886 | Found data for: Puerto Quijarro
# 480 out of 886 | Found data for: Kodinsk
# 481 out of 886 | Found data for: Zhigansk
# 482 out of 886 | Found data for: Alice Springs
# 483 out of 886 | Found data for: Manuk Mangkaw
# 484 out of 886 | Found data for: Axim
# 485 out of 886 | Found data for: Ngunguru
# 486 out of 886 | Found data for: Mankera
# 487 out of 886 | Found data for: College Place
# 488 out of 886 | Found data for: Plouzane
# 489 out of 886 | Found data for: Cockburn Town
# 490 out of 886 | Found data for: Talnakh
# 491 out of 886 | Found data for: Ancud
# 492 out of 886 | Found data for: Oranjestad
# 493 out of 886 | Found data for: Ygatimi
# 494 out of 886 | Found data for: Teahupoo
# 495 out of 886 | Found data for: Lyuban
# 496 out of 886 | Found data for: Egvekinot
# 497 out of 886 | Found data for: Bafq
# 498 out of 886 | Found data for: Kondinskoye
# 499 out of 886 | Found data for: Los Llanos De Aridane
# 500 out of 886 | Found data for: Port Macquarie
# 501 out of 886 | Found data for: Kendari
# 502 out of 886 | Found data for: Latung
# 503 out of 886 | Found data for: Shimoda
# No data for index (504)... skipping.
# No data for index (505)... skipping.
# 506 out of 886 | Found data for: Asuncion
# No data for index (507)... skipping.
# 508 out of 886 | Found data for: Wilmington
# 509 out of 886 | Found data for: Nuuk
# 510 out of 886 | Found data for: Brae
# 511 out of 886 | Found data for: Imeni Babushkina
# 512 out of 886 | Found data for: Aden
# 513 out of 886 | Found data for: Verkhnyaya Inta
# 514 out of 886 | Found data for: Rosario
# 515 out of 886 | Found data for: Chaozhou
# 516 out of 886 | Found data for: Yulara
# 517 out of 886 | Found data for: Brest
# 518 out of 886 | Found data for: Saint-Francois
# No data for index (519)... skipping.
# 520 out of 886 | Found data for: Katsuura
# 521 out of 886 | Found data for: Granville
# 522 out of 886 | Found data for: Tyrma
# 523 out of 886 | Found data for: Aleksandrovsk-Sakhalinskiy
# 524 out of 886 | Found data for: Mataram
# 525 out of 886 | Found data for: Dolzhanskaya
# 526 out of 886 | Found data for: Beyneu
# 527 out of 886 | Found data for: Natal
# 528 out of 886 | Found data for: Stawell
# 529 out of 886 | Found data for: Behren-Les-Forbach
# 530 out of 886 | Found data for: Saint-Augustin
# 531 out of 886 | Found data for: Fort Nelson
# 532 out of 886 | Found data for: Ballybofey
# 533 out of 886 | Found data for: Crateus
# 534 out of 886 | Found data for: Imbituba
# 535 out of 886 | Found data for: Las Margaritas
# 536 out of 886 | Found data for: Zaozerne
# 537 out of 886 | Found data for: Kathmandu
# 538 out of 886 | Found data for: Souillac
# 539 out of 886 | Found data for: Perth
# No data for index (540)... skipping.
# 541 out of 886 | Found data for: Port Pirie
# No data for index (542)... skipping.
# 543 out of 886 | Found data for: Southampton
# 544 out of 886 | Found data for: Gat
# 545 out of 886 | Found data for: London
# 546 out of 886 | Found data for: Green River
# 547 out of 886 | Found data for: Kamenka
# 548 out of 886 | Found data for: Gaoual
# 549 out of 886 | Found data for: Launceston
# 550 out of 886 | Found data for: Muli
# 551 out of 886 | Found data for: Clarksburg
# 552 out of 886 | Found data for: Bhuj
# 553 out of 886 | Found data for: Jalu
# 554 out of 886 | Found data for: Livani
# 555 out of 886 | Found data for: Yibin
# 556 out of 886 | Found data for: Sola
# No data for index (557)... skipping.
# 558 out of 886 | Found data for: Luganville
# 559 out of 886 | Found data for: Berestechko
# 560 out of 886 | Found data for: Pyaozerskiy
# 561 out of 886 | Found data for: Benalla
# 562 out of 886 | Found data for: Zharkent
# 563 out of 886 | Found data for: Wufeng
# 564 out of 886 | Found data for: Clyde River
# 565 out of 886 | Found data for: Ola
# 566 out of 886 | Found data for: Beloha
# 567 out of 886 | Found data for: Bambous Virieux
# 568 out of 886 | Found data for: Mafinga
# 569 out of 886 | Found data for: Tazovskiy
# 570 out of 886 | Found data for: Bima
# 571 out of 886 | Found data for: West Wendover
# 572 out of 886 | Found data for: Seoul
# 573 out of 886 | Found data for: Chapais
# 574 out of 886 | Found data for: Nelson Bay
# No data for index (575)... skipping.
# 576 out of 886 | Found data for: Aklavik
# 577 out of 886 | Found data for: Kununurra
# 578 out of 886 | Found data for: Beaumont
# 579 out of 886 | Found data for: Alihe
# 580 out of 886 | Found data for: Bolobo
# 581 out of 886 | Found data for: Damietta
# 582 out of 886 | Found data for: Saint-Pierre
# 583 out of 886 | Found data for: Kazachinskoye
# 584 out of 886 | Found data for: Marsaxlokk
# 585 out of 886 | Found data for: Dongsheng
# 586 out of 886 | Found data for: Lindi
# 587 out of 886 | Found data for: Bardiyah
# 588 out of 886 | Found data for: Mantua
# 589 out of 886 | Found data for: Rapid Valley
# 590 out of 886 | Found data for: Kathu
# 591 out of 886 | Found data for: Nosy Varika
# 592 out of 886 | Found data for: Nador
# 593 out of 886 | Found data for: Butterworth
# 594 out of 886 | Found data for: Ostrovnoy
# 595 out of 886 | Found data for: San Severo
# 596 out of 886 | Found data for: Muros
# 597 out of 886 | Found data for: North Bend
# 598 out of 886 | Found data for: Takoradi
# 599 out of 886 | Found data for: Proletariy
# 600 out of 886 | Found data for: Pisco
# 601 out of 886 | Found data for: Chernyshevskiy
# 602 out of 886 | Found data for: Riyadh
# 603 out of 886 | Found data for: Pascagoula
# 604 out of 886 | Found data for: Lencois Paulista
# 605 out of 886 | Found data for: Kaeo
# 606 out of 886 | Found data for: Hearst
# 607 out of 886 | Found data for: Coihaique
# 608 out of 886 | Found data for: Betare Oya
# 609 out of 886 | Found data for: Spring Hill
# 610 out of 886 | Found data for: Biloela
# 611 out of 886 | Found data for: Fortuna
# 612 out of 886 | Found data for: Severo-Kurilsk
# 613 out of 886 | Found data for: Nanakuli
# 614 out of 886 | Found data for: Petrolina
# 615 out of 886 | Found data for: Conceicao Do Araguaia
# 616 out of 886 | Found data for: Usinsk
# 617 out of 886 | Found data for: Kananga
# 618 out of 886 | Found data for: Iglesias
# 619 out of 886 | Found data for: Isangel
# 620 out of 886 | Found data for: Sarakhs
# 621 out of 886 | Found data for: Broken Hill
# 622 out of 886 | Found data for: Sonepur
# 623 out of 886 | Found data for: Tommot
# 624 out of 886 | Found data for: La Reforma
# 625 out of 886 | Found data for: La Crosse
# 626 out of 886 | Found data for: Chistoye
# 627 out of 886 | Found data for: Springfield
# 628 out of 886 | Found data for: Cortland
# 629 out of 886 | Found data for: Denpasar
# 630 out of 886 | Found data for: Rongcheng
# 631 out of 886 | Found data for: Ghorawal
# 632 out of 886 | Found data for: Ipua
# 633 out of 886 | Found data for: Farafangana
# 634 out of 886 | Found data for: Bikapur
# 635 out of 886 | Found data for: Rio Grande
# 636 out of 886 | Found data for: Kachug
# 637 out of 886 | Found data for: Melilla
# 638 out of 886 | Found data for: San Roque
# 639 out of 886 | Found data for: Awjilah
# 640 out of 886 | Found data for: Pangoa
# 641 out of 886 | Found data for: Alofi
# 642 out of 886 | Found data for: Qaqortoq
# 643 out of 886 | Found data for: Tigil
# 644 out of 886 | Found data for: Letterkenny
# 645 out of 886 | Found data for: Dunedin
# 646 out of 886 | Found data for: Mount Isa
# 647 out of 886 | Found data for: Monroe
# 648 out of 886 | Found data for: Mishan
# 649 out of 886 | Found data for: Naryan-Mar
# 650 out of 886 | Found data for: Vestmannaeyjar
# 651 out of 886 | Found data for: Venado Tuerto
# 652 out of 886 | Found data for: Tello
# 653 out of 886 | Found data for: Tucuma
# 654 out of 886 | Found data for: Sfantu Gheorghe
# 655 out of 886 | Found data for: Reserva
# 656 out of 886 | Found data for: Santa Rosa De Viterbo
# 657 out of 886 | Found data for: Kokkola
# 658 out of 886 | Found data for: Novovarshavka
# 659 out of 886 | Found data for: Grand Baie
# 660 out of 886 | Found data for: Hobyo
# 661 out of 886 | Found data for: Nassjo
# 662 out of 886 | Found data for: Ler
# 663 out of 886 | Found data for: Rodrigues Alves
# 664 out of 886 | Found data for: Zhicheng
# No data for index (665)... skipping.
# 666 out of 886 | Found data for: Abalak
# 667 out of 886 | Found data for: Portland
# 668 out of 886 | Found data for: Iracoubo
# 669 out of 886 | Found data for: Mana
# 670 out of 886 | Found data for: Luwuk
# 671 out of 886 | Found data for: Tiarei
# 672 out of 886 | Found data for: Porto Velho
# 673 out of 886 | Found data for: Virginia Beach
# No data for index (674)... skipping.
# 675 out of 886 | Found data for: Alpine
# 676 out of 886 | Found data for: Rudbar
# 677 out of 886 | Found data for: Dickinson
# 678 out of 886 | Found data for: Strezhevoy
# 679 out of 886 | Found data for: Moussoro
# 680 out of 886 | Found data for: San Juan De Los Morros
# 681 out of 886 | Found data for: Ahipara
# 682 out of 886 | Found data for: Karoi
# 683 out of 886 | Found data for: Sao Felix Do Xingu
# 684 out of 886 | Found data for: Mahon
# 685 out of 886 | Found data for: Hualmay
# 686 out of 886 | Found data for: Grand Gaube
# 687 out of 886 | Found data for: Nedjo
# No data for index (688)... skipping.
# 689 out of 886 | Found data for: Aras
# 690 out of 886 | Found data for: La Baule-Escoublac
# 691 out of 886 | Found data for: Port Lincoln
# 692 out of 886 | Found data for: Makokou
# 693 out of 886 | Found data for: Charcas
# 694 out of 886 | Found data for: Pizarro
# 695 out of 886 | Found data for: Paciran
# 696 out of 886 | Found data for: Qena
# 697 out of 886 | Found data for: Basoda
# 698 out of 886 | Found data for: Kyaukse
# No data for index (699)... skipping.
# 700 out of 886 | Found data for: Roald
# 701 out of 886 | Found data for: Stabat
# 702 out of 886 | Found data for: Amparafaravola
# 703 out of 886 | Found data for: Gravdal
# 704 out of 886 | Found data for: Makat
# 705 out of 886 | Found data for: Tadine
# 706 out of 886 | Found data for: Saint-Paul
# 707 out of 886 | Found data for: Okhotsk
# 708 out of 886 | Found data for: Naifaru
# 709 out of 886 | Found data for: Senno
# 710 out of 886 | Found data for: Emerald
# 711 out of 886 | Found data for: San Ramon De La Nueva Oran
# 712 out of 886 | Found data for: Sann
# 713 out of 886 | Found data for: Sarh
# 714 out of 886 | Found data for: Kochevo
# 715 out of 886 | Found data for: Danshui
# 716 out of 886 | Found data for: Xai-Xai
# 717 out of 886 | Found data for: Aykhal
# 718 out of 886 | Found data for: Campbellton
# 719 out of 886 | Found data for: Abnub
# 720 out of 886 | Found data for: Pinotepa Nacional
# No data for index (721)... skipping.
# 722 out of 886 | Found data for: Noumea
# 723 out of 886 | Found data for: Siimusti
# 724 out of 886 | Found data for: Arvika
# 725 out of 886 | Found data for: Shamary
# 726 out of 886 | Found data for: Turukhansk
# 727 out of 886 | Found data for: Lazaro Cardenas
# 728 out of 886 | Found data for: Byron Bay
# 729 out of 886 | Found data for: Genhe
# 730 out of 886 | Found data for: Vila
# 731 out of 886 | Found data for: Ninghai
# 732 out of 886 | Found data for: Sorong
# 733 out of 886 | Found data for: Paris
# 734 out of 886 | Found data for: Yenagoa
# 735 out of 886 | Found data for: Georgiyevskoye
# 736 out of 886 | Found data for: Lagoa
# 737 out of 886 | Found data for: Shu
# 738 out of 886 | Found data for: Xining
# 739 out of 886 | Found data for: Moron
# 740 out of 886 | Found data for: Vestmanna
# 741 out of 886 | Found data for: Ipanema
# 742 out of 886 | Found data for: Kiunga
# 743 out of 886 | Found data for: Coroneo
# 744 out of 886 | Found data for: Carutapera
# 745 out of 886 | Found data for: Ilhabela
# 746 out of 886 | Found data for: Carlisle
# No data for index (747)... skipping.
# 748 out of 886 | Found data for: Kutum
# 749 out of 886 | Found data for: Asyut
# 750 out of 886 | Found data for: Wajima
# No data for index (751)... skipping.
# 752 out of 886 | Found data for: Vardo
# 753 out of 886 | Found data for: Pandan Niog
# 754 out of 886 | Found data for: Vila Franca Do Campo
# 755 out of 886 | Found data for: Vesoul
# 756 out of 886 | Found data for: Yichang
# 757 out of 886 | Found data for: Sena Madureira
# 758 out of 886 | Found data for: Buenos Aires
# 759 out of 886 | Found data for: Cefalu
# 760 out of 886 | Found data for: Athni
# 761 out of 886 | Found data for: Safaga
# 762 out of 886 | Found data for: Tsiroanomandidy
# 763 out of 886 | Found data for: Muriwai Beach
# 764 out of 886 | Found data for: Qidong
# 765 out of 886 | Found data for: Kahului
# 766 out of 886 | Found data for: Serik
# No data for index (767)... skipping.
# 768 out of 886 | Found data for: Lahat
# 769 out of 886 | Found data for: Birin
# 770 out of 886 | Found data for: Wasilla
# 771 out of 886 | Found data for: Alekseyevsk
# 772 out of 886 | Found data for: Guamuchil
# 773 out of 886 | Found data for: Irece
# 774 out of 886 | Found data for: Aswan
# 775 out of 886 | Found data for: Prado
# 776 out of 886 | Found data for: Polonnaruwa
# 777 out of 886 | Found data for: Uyuni
# No data for index (778)... skipping.
# 779 out of 886 | Found data for: Rawah
# 780 out of 886 | Found data for: Mayumba
# 781 out of 886 | Found data for: Mitsamiouli
# 782 out of 886 | Found data for: Varnavino
# 783 out of 886 | Found data for: Karasuyama
# 784 out of 886 | Found data for: Moissala
# 785 out of 886 | Found data for: Shimoga
# 786 out of 886 | Found data for: Miraflores
# 787 out of 886 | Found data for: Husavik
# 788 out of 886 | Found data for: Manaquiri
# 789 out of 886 | Found data for: Akyab
# 790 out of 886 | Found data for: Pasighat
# 791 out of 886 | Found data for: Ochtrup
# 792 out of 886 | Found data for: Ryotsu
# 793 out of 886 | Found data for: Dutlwe
# 794 out of 886 | Found data for: Minab
# 795 out of 886 | Found data for: Vigrestad
# 796 out of 886 | Found data for: Aksu
# No data for index (797)... skipping.
# 798 out of 886 | Found data for: Ouidah
# 799 out of 886 | Found data for: Binghamton
# 800 out of 886 | Found data for: Nekrasovka
# 801 out of 886 | Found data for: Zmeinogorsk
# 802 out of 886 | Found data for: Doha
# 803 out of 886 | Found data for: Mardin
# 804 out of 886 | Found data for: Praia
# 805 out of 886 | Found data for: Krasnoselkup
# 806 out of 886 | Found data for: Filadelfia
# 807 out of 886 | Found data for: Hazorasp
# 808 out of 886 | Found data for: Piacabucu
# 809 out of 886 | Found data for: Caborca
# 810 out of 886 | Found data for: North Branch
# 811 out of 886 | Found data for: Limbang
# 812 out of 886 | Found data for: Arman
# 813 out of 886 | Found data for: Boyolangu
# 814 out of 886 | Found data for: Canberra
# 815 out of 886 | Found data for: Hunterville
# 816 out of 886 | Found data for: Jacareacanga
# 817 out of 886 | Found data for: Korla
# 818 out of 886 | Found data for: Springbok
# 819 out of 886 | Found data for: Magdagachi
# No data for index (820)... skipping.
# 821 out of 886 | Found data for: Kurdzhinovo
# 822 out of 886 | Found data for: Paita
# 823 out of 886 | Found data for: Alyangula
# 824 out of 886 | Found data for: Muhos
# 825 out of 886 | Found data for: Pishva
# 826 out of 886 | Found data for: Pestravka
# 827 out of 886 | Found data for: Lodja
# 828 out of 886 | Found data for: Santiago Del Estero
# 829 out of 886 | Found data for: Abaete
# 830 out of 886 | Found data for: Nicoya
# 831 out of 886 | Found data for: Mandera
# 832 out of 886 | Found data for: Gladstone
# 833 out of 886 | Found data for: Road Town
# No data for index (834)... skipping.
# 835 out of 886 | Found data for: Coffs Harbour
# 836 out of 886 | Found data for: Sunrise Manor
# 837 out of 886 | Found data for: Belyy Yar
# 838 out of 886 | Found data for: Menongue
# 839 out of 886 | Found data for: Akureyri
# 840 out of 886 | Found data for: Adrar
# 841 out of 886 | Found data for: Burnie
# 842 out of 886 | Found data for: Almaznyy
# 843 out of 886 | Found data for: Chimbote
# 844 out of 886 | Found data for: Bangui
# 845 out of 886 | Found data for: Bull Savanna
# 846 out of 886 | Found data for: Bontang
# 847 out of 886 | Found data for: Nemuro
# 848 out of 886 | Found data for: Santa Luzia
# 849 out of 886 | Found data for: Revda
# 850 out of 886 | Found data for: Tubay
# 851 out of 886 | Found data for: Bulgan
# 852 out of 886 | Found data for: Qinhuangdao
# 853 out of 886 | Found data for: Kolondieba
# 854 out of 886 | Found data for: Tura
# 855 out of 886 | Found data for: Khandyga
# 856 out of 886 | Found data for: Savelugu
# 857 out of 886 | Found data for: Kumluca
# 858 out of 886 | Found data for: Ko Samui
# 859 out of 886 | Found data for: Usogorsk
# 860 out of 886 | Found data for: Magway
# 861 out of 886 | Found data for: Lethem
# 862 out of 886 | Found data for: Rundu
# 863 out of 886 | Found data for: Ziarat
# 864 out of 886 | Found data for: Kindu
# 865 out of 886 | Found data for: Trelew
# 866 out of 886 | Found data for: Mao
# 867 out of 886 | Found data for: Finnsnes
# 868 out of 886 | Found data for: Bitung
# 869 out of 886 | Found data for: Masuguru
# 870 out of 886 | Found data for: Bubaque
# 871 out of 886 | Found data for: Pueblo Bello
# 872 out of 886 | Found data for: Clinton
# 873 out of 886 | Found data for: Koshurnikovo
# 874 out of 886 | Found data for: Jieznas
# 875 out of 886 | Found data for: Talakan
# 876 out of 886 | Found data for: Ibiruba
# 877 out of 886 | Found data for: Anjiang
# 878 out of 886 | Found data for: Northam
# 879 out of 886 | Found data for: Altamont
# 880 out of 886 | Found data for: Maloarkhangelsk
# 881 out of 886 | Found data for: Siva
# 882 out of 886 | Found data for: Naro Moru
# 883 out of 886 | Found data for: Reconquista
# No data for index (884)... skipping.
# 885 out of 886 | Found data for: Porirua
# For 886, dropped 69 (7.8% lost)
# Cleaning and saving dataframe...
#             City Country    Lat     Lng          Date  Max Temp  Humidity  \
# 0   punta arenas      CL -53.15  -70.92  1.579645e+09     59.00      47.0
# 1      namatanai      PG  -3.67  152.43  1.579645e+09     83.05      75.0
# 2       falmouth      GB  50.15   -5.07  1.579645e+09     44.01     100.0
# 4  mar del plata      AR -38.00  -57.56  1.579645e+09     69.01      88.0
# 5          sabha      LY  27.04   14.43  1.579645e+09     56.79      39.0
#
#    Clouds  Wind Speed
# 0    40.0       27.51
# 1    49.0        7.96
# 2    73.0        5.82
# 4    90.0       13.87
# 5    37.0       13.02

# %% [markdown]
# ### Importing Fetched Data and Building Dataframe

# %%
weather_df = pd.read_csv(output_data_file)
weather_df.head()
# Out:
#    City_ID           City Country    Lat     Lng          Date  Max Temp  \
# 0        0   punta arenas      CL -53.15  -70.92  1.579645e+09     59.00
# 1        1      namatanai      PG  -3.67  152.43  1.579645e+09     83.05
# 2        2       falmouth      GB  50.15   -5.07  1.579645e+09     44.01
# 3        4  mar del plata      AR -38.00  -57.56  1.579645e+09     69.01
# 4        5          sabha      LY  27.04   14.43  1.579645e+09     56.79
#
#    Humidity  Clouds  Wind Speed
# 0      47.0    40.0       27.51
# 1      75.0    49.0        7.96
# 2     100.0    73.0        5.82
# 3      88.0    90.0       13.87
# 4      39.0    37.0       13.02

# %% [markdown]
# ## Plotting the Data

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.figure()
plt.scatter(weather_df['Lat'],weather_df['Max Temp'],edgecolor='k',color='r',alpha=0.7, label="Cities")
plt.title(f"Latitude vs. Temperature ({now})")
plt.ylabel("Temperature (F)")
plt.savefig("Outputs/LatvTemp.png", transparent=True)
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.figure()
plt.scatter(weather_df['Lat'],weather_df['Humidity'],edgecolor='k',alpha=0.7)
plt.title(f"Latitude vs. Humidity ({now})")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
# plt.ylim(0,110) # Used if there are instances of Oversaturated Air 
plt.savefig("Outputs/LatvHum.png", transparent=True)
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.figure()
plt.scatter(weather_df['Lat'],weather_df['Clouds'],edgecolor='k',color='gray',alpha=0.7)
plt.title(f"Latitude vs. Cloudiness ({now})")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.savefig("Outputs/LatvCloud.png", transparent=True)
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.figure()
plt.scatter(weather_df['Lat'],weather_df['Wind Speed'],edgecolor='k',color='g',alpha=0.7)
plt.title(f"Latitude vs. Wind Speed ({now})")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.savefig("Outputs/LatvWind.png", transparent=True)
plt.show()

# %% [markdown]
# #### Latitude/Longitude Distributions (Map plot)

# %%
plt.figure()
plt.scatter(weather_df['Lng'],weather_df['Lat'],edgecolor='k',color="purple",alpha=0.5)
plt.xlim(-180,180)

plt.title(f"Latitude/Longitude Distribution ({now})")
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.savefig("Outputs/LatLongDist.png", transparent=True)
plt.show()

# %% [markdown]
# #### Latitude/Longitude Distributions (Histogram plot)

# %%
pt, ax = plt.subplots(1,2,sharey=True,figsize=[12.8, 4.8])

ax[0].hist(weather_df['Lat'],bins=20)
ax[0].set_ylabel("Count")
ax[0].set_xlabel("Latitude")
ax[1].hist(weather_df['Lng'],bins=20)
ax[1].set_xlabel("Longitude")
plt.suptitle(f"Latitude/Longitude Historgram ({now})")
plt.savefig("Outputs/LatLnghist.png", transparent=True)
plt.show()

# %% [markdown]
# ----
# # Analysis
#
# ### Trend 1:
# For this randomly selected dataset, I found that max temperatures tend to decrese with increasing latitude, peaking at ~25 degrees latitude. That being said, the positive latitudinal half accounts for the majority of the data, as the Northern Hemisphere has a majority of the landmass. Cloudiness follows a similar trend in the Northern Hemisphere as well, and this may again be attributed to the larger amount of landmass in the Northern Hemisphere.
#
# ### Trend 2:
# Low humidity areas tend to be closer to the equator, with some of the lowest humidity readings coming from between 20-30 degrees North or South of the equator. Lowest humidities tend to go to higher percents outside of the 20-30 degree (North/South). There have been some instances of oversaturated air, where humidity exceeds 100%. Otherwise, humidity tends to be < 60% for most reported latitudes. Windiness does not appear to have a strong correlation with latitudes.
#
# ### Trend 3:
# With over 500 data points, I am able to get a set of data that's well distributed across the continents. That being said, there are some holes in the data. Certain regions of continents don't tend to appear in the data set, and most of these are in scarcely inhabited or inhabitable areas such as the Amazon Rainforest, Sahara Desert, the outback of Austrailia, and Northern regions of Northern Hemisphere continents. Throughout this project, I regularly saw holes in my Latitude/Longitude
# data distribution.
